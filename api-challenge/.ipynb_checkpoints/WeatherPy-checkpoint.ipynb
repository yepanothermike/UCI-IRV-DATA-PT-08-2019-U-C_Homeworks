# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_found = []
temps = []
humidity = []
cloudiness = []
windspeed = []

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# Loop through the list of cities and perform a request for data on each
i = 0
i_found = 0
for city in cities:
    response = requests.get(query_url + city).json()
    if response["cod"] == 200:
        cities_found.append(city)
        temps.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        print(f" ")
        print(f"found record for {cities[i]} ({i+1} of {len(cities)})")
        print(f"Temperature: {temps[i_found]} °F, Humidity: {humidity[i_found]}%, Cloudiness: {cloudiness[i_found]} %, Wind Speed: {windspeed[i_found]} mph")
        i_found += 1
    elif response["cod"] == '404':
        print(f" ")
        print(f"ERROR, no record for {cities[i]}, skipping...")
    i += 1
    
print('----------------------')
print('search complete')
print(f'found temperature data for {len(cities_found)} of {len(cities)} cities searched')
# Out:
#
# found record for hilo (1 of 611)
# Temperature: 68.02 °C, Humidity: 83 %, Cloudiness: 90 %, Wind Speed: 10.29 mph
#
# found record for atuona (2 of 611)
# Temperature: 79.63 °C, Humidity: 76 %, Cloudiness: 12 %, Wind Speed: 10.69 mph
#
# found record for jamestown (3 of 611)
# Temperature: 84.65 °C, Humidity: 16 %, Cloudiness: 8 %, Wind Speed: 8.39 mph
#
# found record for punta arenas (4 of 611)
# Temperature: 41 °C, Humidity: 76 %, Cloudiness: 0 %, Wind Speed: 24.16 mph
#
# found record for kainantu (5 of 611)
# Temperature: 64.28 °C, Humidity: 90 %, Cloudiness: 73 %, Wind Speed: 3.15 mph
#
# found record for okato (6 of 611)
# Temperature: 48 °C, Humidity: 80 %, Cloudiness: 100 %, Wind Speed: 11.01 mph
#
# found record for plouzane (7 of 611)
# Temperature: 49.6 °C, Humidity: 81 %, Cloudiness: 90 %, Wind Speed: 9.17 mph
#
# found record for georgetown (8 of 611)
# Temperature: 75.2 °C, Humidity: 100 %, Cloudiness: 0 %, Wind Speed: 2.24 mph
#
# ERROR, no record for taolanaro, skipping...
#
# found record for tuatapere (10 of 611)
# Temperature: 48.99 °C, Humidity: 90 %, Cloudiness: 72 %, Wind Speed: 7 mph
#
# found record for pokaran (11 of 611)
# Temperature: 92.47 °C, Humidity: 44 %, Cloudiness: 63 %, Wind Speed: 13.73 mph
#
# found record for barrow (12 of 611)
# Temperature: 34.09 °C, Humidity: 84 %, Cloudiness: 0 %, Wind Speed: 6.51 mph
#
# found record for provideniya (13 of 611)
# Temperature: 37.4 °C, Humidity: 86 %, Cloudiness: 75 %, Wind Speed: 11.18 mph
#
# found record for tessalit (14 of 611)
# Temperature: 82.75 °C, Humidity: 13 %, Cloudiness: 33 %, Wind Speed: 6.15 mph
#
# found record for diffa (15 of 611)
# Temperature: 81.38 °C, Humidity: 63 %, Cloudiness: 100 %, Wind Speed: 14.12 mph
#
# ERROR, no record for attawapiskat, skipping...
#
# found record for mareeba (17 of 611)
# Temperature: 74.12 °C, Humidity: 61 %, Cloudiness: 75 %, Wind Speed: 24.16 mph
#
# found record for tiksi (18 of 611)
# Temperature: 24.14 °C, Humidity: 87 %, Cloudiness: 100 %, Wind Speed: 27.31 mph
#
# found record for carnarvon (19 of 611)
# Temperature: 60.25 °C, Humidity: 16 %, Cloudiness: 47 %, Wind Speed: 9.62 mph
#
# found record for albany (20 of 611)
# Temperature: 47.05 °C, Humidity: 57 %, Cloudiness: 90 %, Wind Speed: 9.17 mph
#
# found record for marbella (21 of 611)
# Temperature: 67.75 °C, Humidity: 77 %, Cloudiness: 0 %, Wind Speed: 14.99 mph
#
# found record for clyde river (22 of 611)
# Temperature: 32 °C, Humidity: 98 %, Cloudiness: 90 %, Wind Speed: 9.17 mph
#
# found record for faanui (23 of 611)
# Temperature: 78.17 °C, Humidity: 77 %, Cloudiness: 11 %, Wind Speed: 15.66 mph
#
# found record for victoria (24 of 611)
# Temperature: 87.39 °C, Humidity: 66 %, Cloudiness: 75 %, Wind Speed: 4.7 mph
#
# found record for beringovskiy (25 of 611)
# Temperature: 32.29 °C, Humidity: 65 %, Cloudiness: 91 %, Wind Speed: 5.3 mph
#
# found record for busselton (26 of 611)
# Temperature: 72.91 °C, Humidity: 32 %, Cloudiness: 87 %, Wind Speed: 10.29 mph
#
# found record for cape town (27 of 611)
# Temperature: 56.12 °C, Humidity: 93 %, Cloudiness: 0 %, Wind Speed: 5.82 mph
#
# found record for saldanha (28 of 611)
# Temperature: 52.97 °C, Humidity: 69 %, Cloudiness: 95 %, Wind Speed: 1.95 mph
#
# found record for clyde (29 of 611)
# Temperature: 45 °C, Humidity: 66 %, Cloudiness: 96 %, Wind Speed: 1.01 mph
#
# found record for ushuaia (30 of 611)
# Temperature: 41 °C, Humidity: 65 %, Cloudiness: 0 %, Wind Speed: 29.97 mph
#
# found record for miandrivazo (31 of 611)
# Temperature: 91.35 °C, Humidity: 33 %, Cloudiness: 24 %, Wind Speed: 3.33 mph
#
# found record for huilong (32 of 611)
# Temperature: 76.66 °C, Humidity: 73 %, Cloudiness: 99 %, Wind Speed: 3.04 mph
#
# found record for kilindoni (33 of 611)
# Temperature: 78.98 °C, Humidity: 77 %, Cloudiness: 31 %, Wind Speed: 16.4 mph
#
# found record for linxia (34 of 611)
# Temperature: 61.02 °C, Humidity: 48 %, Cloudiness: 57 %, Wind Speed: 8.14 mph
#
# found record for nishihara (35 of 611)
# Temperature: 82.22 °C, Humidity: 57 %, Cloudiness: 75 %, Wind Speed: 10.29 mph
#
# found record for viedma (36 of 611)
# Temperature: 38.65 °C, Humidity: 68 %, Cloudiness: 0 %, Wind Speed: 9.24 mph
#
# found record for nikolskoye (37 of 611)
# Temperature: 41 °C, Humidity: 86 %, Cloudiness: 75 %, Wind Speed: 11.18 mph
#
# found record for jalu (38 of 611)
# Temperature: 79.38 °C, Humidity: 24 %, Cloudiness: 0 %, Wind Speed: 14.94 mph
#
# ERROR, no record for dolbeau, skipping...
#
# found record for lorengau (40 of 611)
# Temperature: 83.07 °C, Humidity: 71 %, Cloudiness: 51 %, Wind Speed: 2.06 mph
#
# found record for estoril (41 of 611)
# Temperature: 59.27 °C, Humidity: 87 %, Cloudiness: 20 %, Wind Speed: 2.24 mph
#
# found record for grindavik (42 of 611)
# Temperature: 45.46 °C, Humidity: 81 %, Cloudiness: 90 %, Wind Speed: 42.5 mph
#
# found record for whitehorse (43 of 611)
# Temperature: 34.34 °C, Humidity: 69 %, Cloudiness: 20 %, Wind Speed: 4.7 mph
#
# found record for ilebo (44 of 611)
# Temperature: 74.56 °C, Humidity: 85 %, Cloudiness: 100 %, Wind Speed: 1.45 mph
#
# found record for mataura (45 of 611)
# Temperature: 48.99 °C, Humidity: 90 %, Cloudiness: 45 %, Wind Speed: 7 mph
#
# found record for bilibino (46 of 611)
# Temperature: 9.77 °C, Humidity: 91 %, Cloudiness: 100 %, Wind Speed: 7.31 mph
#
# found record for tazovskiy (47 of 611)
# Temperature: 45.54 °C, Humidity: 89 %, Cloudiness: 98 %, Wind Speed: 12.57 mph
#
# ERROR, no record for kamenskoye, skipping...
#
# found record for borgarnes (49 of 611)
# Temperature: 44.85 °C, Humidity: 70 %, Cloudiness: 90 %, Wind Speed: 19.46 mph
#
# found record for torbay (50 of 611)
# Temperature: 39.83 °C, Humidity: 100 %, Cloudiness: 90 %, Wind Speed: 12.75 mph
#
# found record for geraldton (51 of 611)
# Temperature: 32 °C, Humidity: 83 %, Cloudiness: 90 %, Wind Speed: 4.7 mph
#
# found record for samana (52 of 611)
# Temperature: 70.22 °C, Humidity: 96 %, Cloudiness: 100 %, Wind Speed: 1.97 mph
#
# found record for muros (53 of 611)
# Temperature: 53.11 °C, Humidity: 100 %, Cloudiness: 40 %, Wind Speed: 4.7 mph
#
# found record for saskylakh (54 of 611)
# Temperature: 20.7 °C, Humidity: 79 %, Cloudiness: 3 %, Wind Speed: 1.61 mph
#
# found record for road town (55 of 611)
# Temperature: 81.52 °C, Humidity: 78 %, Cloudiness: 20 %, Wind Speed: 3.36 mph
#
# found record for khatanga (56 of 611)
# Temperature: 27 °C, Humidity: 58 %, Cloudiness: 0 %, Wind Speed: 9.06 mph
#
# found record for changde (57 of 611)
# Temperature: 93.71 °C, Humidity: 29 %, Cloudiness: 0 %, Wind Speed: 3.76 mph
#
# found record for rocha (58 of 611)
# Temperature: 47.54 °C, Humidity: 92 %, Cloudiness: 45 %, Wind Speed: 7.9 mph
#
# found record for dikson (59 of 611)
# Temperature: 28.04 °C, Humidity: 66 %, Cloudiness: 100 %, Wind Speed: 26.06 mph
#
# found record for namibe (60 of 611)
# Temperature: 65.18 °C, Humidity: 80 %, Cloudiness: 54 %, Wind Speed: 2.75 mph
#
# found record for vaini (61 of 611)
# Temperature: 80.6 °C, Humidity: 69 %, Cloudiness: 40 %, Wind Speed: 3.36 mph
#
# ERROR, no record for polikhnitos, skipping...
#
# found record for lata (63 of 611)
# Temperature: 44.39 °C, Humidity: 66 %, Cloudiness: 42 %, Wind Speed: 9.28 mph
#
# found record for cayenne (64 of 611)
# Temperature: 75.2 °C, Humidity: 94 %, Cloudiness: 0 %, Wind Speed: 4.25 mph
#
# found record for abriaqui (65 of 611)
# Temperature: 69.52 °C, Humidity: 98 %, Cloudiness: 100 %, Wind Speed: 0.31 mph
#
# found record for dobra (66 of 611)
# Temperature: 45.61 °C, Humidity: 93 %, Cloudiness: 90 %, Wind Speed: 5.82 mph
#
# ERROR, no record for mys shmidta, skipping...
#
# found record for santiago de cao (68 of 611)
# Temperature: 60.8 °C, Humidity: 93 %, Cloudiness: 40 %, Wind Speed: 8.05 mph
#
# found record for chazuta (69 of 611)
# Temperature: 62.6 °C, Humidity: 290 %, Cloudiness: 20 %, Wind Speed: 4.7 mph
#
# found record for hermanus (70 of 611)
# Temperature: 54.21 °C, Humidity: 77 %, Cloudiness: 21 %, Wind Speed: 10.4 mph
#
# found record for cidreira (71 of 611)
# Temperature: 63.22 °C, Humidity: 93 %, Cloudiness: 100 %, Wind Speed: 6.78 mph
#
# found record for bluff (72 of 611)
# Temperature: 82.89 °C, Humidity: 23 %, Cloudiness: 0 %, Wind Speed: 15.48 mph
#
# found record for hervey bay (73 of 611)
# Temperature: 76.26 °C, Humidity: 38 %, Cloudiness: 0 %, Wind Speed: 14.99 mph
#
# found record for pleasant point (74 of 611)
# Temperature: 45.16 °C, Humidity: 93 %, Cloudiness: 90 %, Wind Speed: 5.82 mph
#
# found record for brigantine (75 of 611)
# Temperature: 72.03 °C, Humidity: 100 %, Cloudiness: 90 %, Wind Speed: 10.29 mph
#
# ERROR, no record for belushya guba, skipping...
#
# found record for hithadhoo (77 of 611)
# Temperature: 82.64 °C, Humidity: 79 %, Cloudiness: 95 %, Wind Speed: 16.15 mph
#
# found record for chandpur (78 of 611)
# Temperature: 89.15 °C, Humidity: 62 %, Cloudiness: 1 %, Wind Speed: 7.74 mph
#
# found record for rikitea (79 of 611)
# Temperature: 66.69 °C, Humidity: 76 %, Cloudiness: 66 %, Wind Speed: 14.74 mph
#
# found record for sisimiut (80 of 611)
# Temperature: 41.58 °C, Humidity: 62 %, Cloudiness: 0 %, Wind Speed: 3.36 mph
#
# found record for yellowknife (81 of 611)
# Temperature: 46.22 °C, Humidity: 65 %, Cloudiness: 75 %, Wind Speed: 8.05 mph
#
# found record for east london (82 of 611)
# Temperature: 62.6 °C, Humidity: 77 %, Cloudiness: 98 %, Wind Speed: 16.11 mph
#
# ERROR, no record for urdzhar, skipping...
#
# found record for mikhaylovka (84 of 611)
# Temperature: 46.24 °C, Humidity: 41 %, Cloudiness: 36 %, Wind Speed: 5.28 mph

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
